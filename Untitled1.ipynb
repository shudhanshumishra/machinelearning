# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel(r"C:\Users\hp\Documents\knn\student_info.xlsx")
data
# Out:
#      study_hours  student_marks Result
# 0           6.83          78.50   Pass
# 1           6.56          76.74   Pass
# 2            NaN          78.68   Pass
# 3           5.67          71.82   Fail
# 4           8.67          84.19   Pass
# ..           ...            ...    ...
# 195         7.53          81.67   Pass
# 196         8.56          84.68   Pass
# 197         8.94          86.75   Pass
# 198         6.60          78.05   Pass
# 199         8.35          83.50   Pass
#
# [200 rows x 3 columns]

# %%
data.isnull().sum()
# Out:
# study_hours      7
# student_marks    8
# Result           2
# dtype: int64

# %%
data["study_hours"].mean()
# Out:
# 6.994715025906736

# %%
data["student_marks"].mean()
# Out:
# 77.96130208333334

# %%
data["study_hours"]=data["study_hours"].fillna(data["study_hours"].mean())
data["student_marks"]=data["student_marks"].fillna(data["student_marks"].mean())

# %%
data.isnull().mean()
# Out:
# study_hours      0.00
# student_marks    0.00
# Result           0.01
# dtype: float64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# study_hours      0
# student_marks    0
# Result           0
# dtype: int64

# %%
data["Result"].unique()
# Out:
# array(['Pass', 'Fail'], dtype=object)

# %%
#data visualisation
sns.countplot(data["Result"])
# Out:
# <Axes: xlabel='count', ylabel='Result'>

# %%
sns.scatterplot(x="study_hours",y="student_marks",data=data)
# Out:
# <Axes: xlabel='study_hours', ylabel='student_marks'>

# %%
sns.scatterplot(x="study_hours",y="student_marks",data=data,hue="Result")
# Out:
# <Axes: xlabel='study_hours', ylabel='student_marks'>

# %%
#machine learning
x=data[["study_hours","student_marks"]]
y=data[["Result"]]

# %%
#split dataset:
from sklearn.model_selection import train_test_split
x_train,y_train,x_test,y_test=train_test_split(x,y,train_size=0.7)

# %%
data.shape
# Out:
# (198, 3)

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((138, 2), (60, 2), (138, 1), (60, 1))

# %%
#ml model creation:
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 4
#       2 from sklearn.neighbors import KNeighborsClassifier
#       3 model=KNeighborsClassifier()
# ----> 4 model.fit(x_train,y_train)
#
# File ~\anaconda3\New folder\New folder\New folder\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\New folder\New folder\New folder\Lib\site-packages\sklearn\neighbors\_classification.py:238, in KNeighborsClassifier.fit(self, X, y)
#     216 @_fit_context(
# ...
